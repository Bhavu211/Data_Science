# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhavu211/Data_Science/blob/main/GFGPythonfor_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(12)
# Out:
# 12

# %%
print("Bhawna Mangla")
# Out:
# Bhawna Mangla

# %% [markdown]
# # Datatypes in Python
# 4 datattypes
# integer
# float
# string
# boolean

# %%
print(12)
print("Bhavu")
print(True)
# Out:
# 12
# Bhavu
# True

# %%
print("BHawna" ,123)
# Out:
# BHawna 123

# %%
print("Bhawna","Mangla")
# Out:
# Bhawna Mangla

# %%
print("BHawna""Mangla")
# Out:
# BHawnaMangla

# %% [markdown]
# Concat without comma

# %%
print(123)
print()
print('Bhawna')
# Out:
# 123
#
# Bhawna

# %% [markdown]
# print(), \n - Enter space, \t - tab

# %%
print("Bhawna\n\n Mangla")
# Out:
# Bhawna
#
#  Mangla

# %%
print("BHawna\n\t Mangla")
# Out:
# BHawna
# 	 Mangla

# %%
print("Bhawna Mangla", end = '-')
print(12)
# Out:
# Bhawna Mangla-12

# %%
print("Bhawna Mangla", end = '-')
print(12, end = '|')
print("Bhawna")
print("Mangla")
# Out:
# Bhawna Mangla-12|Bhawna
# Mangla

# %%
type(12),
# Out:
# (int,)

# %%
type("Bhawna"),
# Out:
# (str,)

# %%
#Operators
# int, int
print(3+5)
print(3-5)
print(3*5)
print(3/5)
print(3//5)
print(3 %5)
print(3 ** 5)

# int, float
print(3+5.5)
print(3-5.5)
print(3*5.5)
print(3/5.5)
print(3//5.5)
print(3 %5.5)
print(3 ** 5.5)

# int, string
# int, bool

#Operators
# int, int
print(3+5)
print(3-5)
print(3*5)
print(3/5)
print(3//5)
print(3 %5)
print(3 ** 5)



# int, float
print(3+5.5)
print(3-5.5)
print(3*5.5)
print(3/5.5)
print(3//5.5)
print(3 %5.5)
print(3 ** 5.5)

# int, string
# Only multiply and boolean can happen
print(5*"Bhawna")

# int, bool
print(10+True)
print(10-True)
print(10*True)
print(10*(True+True))
print(10/True)
print(10//True)
print(10 **True)
# Out:
# 8
# -2
# 15
# 0.6
# 0
# 3
# 243
# 8.5
# -2.5
# 16.5
# 0.5454545454545454
# 0.0
# 3.0
# 420.8883462392372
# 8
# -2
# 15
# 0.6
# 0
# 3
# 243
# 8.5
# -2.5
# 16.5
# 0.5454545454545454
# 0.0
# 3.0
# 420.8883462392372
# BhawnaBhawnaBhawnaBhawnaBhawna
# 11
# 9
# 10
# 20
# 10.0
# 10
# 10

# %% [markdown]
# #Operators
# # int, int
# print(3+5)
# print(3-5)
# print(3*5)
# print(3/5)
# print(3//5)
# print(3 %5)
# print(3 ** 5)
#
#
#
# # int, float
# print(3+5.5)
# print(3-5.5)
# print(3*5.5)
# print(3/5.5)
# print(3//5.5)
# print(3 %5.5)
# print(3 ** 5.5)
#
# # int, string
# # Only multiply and boolean can happen
# print(5*"Bhawna")
#
# # int, bool
# print(10+True)
# print(10-True)
# print(10*True)
# print(10*(True+True))
# print(10/True)
# print(10//True)
# print(10 **True)

# %%
print(True + 5.5)
# Out:
# 6.5

# %% [markdown]
# str - bool, float
# float - str, bool
# bool - str, float

# %%
print("Bhawna"*True)
print("Mangla"*False)
# Out:
# Bhawna

# %%
print(7.5 + True)
# Out:
# 8.5

# %%
a=5
print(a+5)
print(a)
# Out:
# 10
# 5

# %% [markdown]
# 2.1 Comparison Operators
#
# print(10)
# a +=2

# %% [markdown]
# Logical operators

# %%
num=35
print((num%5==0) and (num%7==0))
print((num%5==0) and (num%7==0) and (num%2==0))
print((num%5==0) and (num%7==0) and (num%2==0) and num<=100)
# Out:
# True
# False
# False

# %%
name='Bhawna Mangla'
for i in range(len(name)-1,-1,-1):
  print(name[i], end='')

#first parameter(last), where we want to end (0-1), step size(-1)
# Out:
# algnaM anwahB

# %%
name= 'Bhawna'
for i in range(-1,-len(name)-1,-1):
  print(name[i], end='')
#-1 -> last character
# -len(name) if 15 charaters , we go till -15, so tht last haracter can be included, so -1 s added, stepsize- -1
# Out:
# anwahB

# %%
lst=[[1,2,3],[4,5,6]]
print(lst[1][1])
# Out:
# 5

# %% [markdown]
# **Python for Data Science**
#
# Data analyst- Analyse data that is already given
# Data scientist- Predict using old data
#
# Data Analyst
# -Agenda|Problem Statement
# -Finding KPIs
# 1. Finding Last year sales gender wise
# 2. Age Category(18-25)(26-35)
# 3. Courses(DSA,DA,DS)
# 4. Season
# 5. Trend(Feedbacks|Poles)
#
# -Requirement gathering
# 1. Last year sales(Location, Gender, DOB, Course, Date, Day, Time)
# 2. Trends
#
# -Data Gathering
# -Explore Data
# -Transform /Cleaning
# -Analyze
# -Visualization
#
#
# Data Scientist
# Agenda
# KPIs-
# 1.Historic data
# Data Gathering
# -Explore Data
# -Transform /Cleaning
# -Analyze
# -Visualization
# -ML algorithm
# -Evaluation
# -Final algorithm

# %% [markdown]
# Data Loading
#
# Clone from github
# oor direct from google drive by-
#
# from google.colab

# %%
# !git clone https://github.com/AshishJangra27/datasets
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 328, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 328 (delta 19), reused 54 (delta 9), pack-reused 235 (from 1)
# Receiving objects: 100% (328/328), 278.62 MiB | 16.11 MiB/s, done.
# Resolving deltas: 100% (145/145), done.
# Updating files: 100% (225/225), done.

# %%
import pandas as pd

# %%
dir(pandas)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_built_with_meson',
#  '_config',
# ...

# %%
df= pd.read_csv('/content/datasets/Airbnb/airbnb_v2.csv')

# %%
df
# Out:
#        Unnamed: 0        id  \
# 0               0  49849504
# 1               1  50891766
# 2               2  50699164
# 3               3  49871422
# 4               4  51245886
# ...           ...       ...
# 12800       12800  44697740
# 12801       12801  29975283
# 12802       12802  32977697
# 12803       12803   8006146
# 12804       12804  40547903
#
#                                                     name rating reviews  \
# 0                                         Perla bungalov   4.71      64
# 1      Authentic Beach Architect Sheltered Villa with...    New       0
# 2                                      cottages sataplia   4.85      68
# 3                            Sapanca Breathable Bungalow    5.0      13
# 4                                          Bungalov Ev 2    New       0
# ...                                                  ...    ...     ...
# 12800            Brown Dome House No. 3, full of healing   4.94      16
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  49849504                                     Perla bungalov
# 1           1  50891766  Authentic Beach Architect Sheltered Villa with...
# 2           2  50699164                                  cottages sataplia
# 3           3  49871422                        Sapanca Breathable Bungalow
# 4           4  51245886                                      Bungalov Ev 2
#
#   rating reviews    host_name      host_id                   address  \
# 0   4.71      64    Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1    New       0        Fatih  386223873.0      Kaş, Antalya, Turkey
# 2   4.85      68       Giorgi  409690853.0          Imereti, Georgia
# 3    5.0      13        Melih  401873242.0  Sapanca, Sakarya, Turkey
# 4    New       0  Arp Sapanca  414884116.0  Sapanca, Sakarya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  49849504                                     Perla bungalov
# 1           1  50891766  Authentic Beach Architect Sheltered Villa with...
# 2           2  50699164                                  cottages sataplia
#
#   rating reviews  host_name      host_id                   address  \
# 0   4.71      64  Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1    New       0      Fatih  386223873.0      Kaş, Antalya, Turkey
# 2   4.85      68     Giorgi  409690853.0          Imereti, Georgia
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# 1  4 guests,2 bedrooms,2 beds,2 bathrooms
# 2    4 guests,1 bedroom,3 beds,1 bathroom
#
#                                            amenities  ... price   country  \
# 0  Mountain view,Valley view,Lake access,Kitchen,...  ...  8078    Turkey
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'rating', 'reviews', 'host_name', 'host_id',
#        'address', 'features', 'amenities', 'safety_rules', 'hourse_rules',
#        'img_links', 'price', 'country', 'bathrooms', 'beds', 'guests',
#        'toiles', 'bedrooms', 'studios', 'checkin', 'checkout'],
#       dtype='object')

# %%
df['Unnamed: 0']
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 12800    12800
# 12801    12801
# 12802    12802
# 12803    12803
# 12804    12804
# Name: Unnamed: 0, Length: 12805, dtype: int64

# %%
df['name']
# Out:
# 0                                           Perla bungalov
# 1        Authentic Beach Architect Sheltered Villa with...
# 2                                        cottages sataplia
# 3                              Sapanca Breathable Bungalow
# 4                                            Bungalov Ev 2
#                                ...
# 12800              Brown Dome House No. 3, full of healing
# 12801         Bubble Hotel Ubud with Bathtub under the Sky
# 12802                                     Paradise Eco Hub
# 12803       WisDOME - Mentigi Bay Village - Gilis - Lombok
# 12804     Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]
# Name: name, Length: 12805, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12805 entries, 0 to 12804
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    12805 non-null  int64
#  1   id            12805 non-null  int64
#  2   name          12805 non-null  object
#  3   rating        12805 non-null  object
#  4   reviews       12805 non-null  object
#  5   host_name     12797 non-null  object
#  6   host_id       12805 non-null  float64
#  7   address       12805 non-null  object
#  8   features      12805 non-null  object
#  9   amenities     12805 non-null  object
#  10  safety_rules  12805 non-null  object
#  11  hourse_rules  12805 non-null  object
#  12  img_links     12805 non-null  object
#  13  price         12805 non-null  int64
#  14  country       12805 non-null  object
#  15  bathrooms     12805 non-null  int64
#  16  beds          12805 non-null  int64
#  17  guests        12805 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# id                 0
# name               0
# rating             0
# reviews            0
# host_name          8
# host_id            0
# address            0
# features           0
# amenities          0
# safety_rules       0
# hourse_rules       0
# img_links          0
# price              0
# country            0
# bathrooms          0
# beds               0
# guests             0
# toiles             0
# bedrooms           0
# studios            0
# checkin          800
# checkout        2450
# dtype: int64

# %%
del df['host_name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('host_name', 'checkin', 'checkout')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-826be4d2db15> in <cell line: 0>()
# ----> 1 del df['host_name','checkin', 'checkout']
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# id                 0
# name               0
# rating             0
# reviews            0
# host_id            0
# address            0
# features           0
# amenities          0
# safety_rules       0
# hourse_rules       0
# img_links          0
# price              0
# country            0
# bathrooms          0
# beds               0
# guests             0
# toiles             0
# bedrooms           0
# studios            0
# checkin          800
# checkout        2450
# dtype: int64

# %%
del df['checkin']
del df[ 'checkout']

# %%
len(df['id'].unique())
# Out:
# 12805

# %%
df['id'].unique()
# Out:
# array([49849504, 50891766, 50699164, ..., 32977697,  8006146, 40547903])

# %%
df['id'].count()
# Out:
# np.int64(12805)

# %%
df['id'].nunique()
# Out:
# 12805

# %% [markdown]
# 1. Data cleaning
# remove null and duplicate values in id

# %%
jobs=pd.read_csv('/content/datasets/Job Postings/jobs.csv.zip')

# %%
jobs['salary'].value_counts()
# Out:
# salary
# Not disclosed                                          45544
# 6,50,000 - 9,00,000 PA.                                 3330
# 6,00,000 - 8,00,000 PA.                                 1114
# 5,00,000 - 10,00,000 PA.                                1087
# 2,50,000 - 3,50,000 PA.                                  599
#                                                        ...
# 4,00,000 - 9,00,000 PA. (Including Variable: 20.0%)        1
# 4,00,00,000 - 4,50,00,000 PA.                              1
# 2,00,000 - 6,00,000 PA. (Including Variable: 30.0%)        1
# 60,00,000 - 1,00,00,000 PA.                                1
# 75,00,000 - 1,00,00,000 PA.                                1
# Name: count, Length: 813, dtype: int64

# %%
jobs
# Out:
#              job_id                                           job_role  \
# 0      7.012301e+10      Branch Banking - Calling For Women Candidates
# 1      6.012391e+10                       Product Owner Senior Manager
# 2      6.012391e+10  Employee Relations and Policies Associate Manager
# 3      6.012391e+10         Employee Relations and Policies Specialist
# 4      6.012301e+10                                  SAP BO Consultant
# ...             ...                                                ...
# 79142  6.012301e+10                           .Net Fullstack Developer
# 79143  1.122201e+10        Senior (BI) Business Intelligence Architect
# 79144  1.512220e+11                                  PowerBI Developer
# 79145  2.712220e+11                         Customer Service Associate
# 79146  2.112220e+11                   Senior Java BED ( PAN India)- KG
#
#                      company experience                     salary  \
# ...

# %%
jobs[jobs['salary']!= 'Not disclosed']
# Out:
#              job_id                                           job_role  \
# 19     6.012301e+10                           .Net Fullstack Developer
# 21     5.012301e+10  Hexaware Technologies || Azure DataBricks_Pysp...
# 23     3.112220e+11  Deputy Manager- Marketing (Digital & B2B)-Indu...
# 24     2.712220e+11                         Customer Service Associate
# 25     2.112220e+11                   Senior Java BED ( PAN India)- KG
# ...             ...                                                ...
# 79125  2.712220e+11                         Customer Service Associate
# 79126  2.112220e+11                   Senior Java BED ( PAN India)- KG
# 79142  6.012301e+10                           .Net Fullstack Developer
# 79145  2.712220e+11                         Customer Service Associate
# 79146  2.112220e+11                   Senior Java BED ( PAN India)- KG
#
#                      company experience  \
# 19                Citiustech    3-8 Yrs
# ...

# %%
jobs['salary']!= 'Not disclosed'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 79142     True
# 79143    False
# 79144    False
# 79145     True
# 79146     True
# Name: salary, Length: 79147, dtype: bool

# %%
jobs['salary']== 'Not disclosed'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 79142    False
# 79143     True
# 79144     True
# 79145    False
# 79146    False
# Name: salary, Length: 79147, dtype: bool

# %%
df.dropna()
